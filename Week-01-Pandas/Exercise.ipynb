# %% [markdown]
# # Data wrangling with Pandas exercise
# * For this exercise we will be using the `listings.csv` data file.

# %%
print('hello world')
# Out:
# hello world

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Load in the data file using `pd.read_csv()`

# %%
! open .

# %%
# Load data here

file = pd.read_csv('data/listings.csv', sep=',')

file.head()
# Out:
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2  5121                                    BlissArtsSpace!     7356
# 3  5136           Spacious Brooklyn Duplex, Patio + Garden     7378
# 4  5178                   Large Furnished Room Near B'way　     8967
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown  40.75362  -73.98377
# 1  LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 2        Garon            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 3      Rebecca            Brooklyn         Sunset Park  40.66120  -73.99423
# 4     Shunichi           Manhattan      Hell's Kitchen  40.76489  -73.98493
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ## Exercise 2 - Filtering
#
# Return the following subsets of the dataframe.
#
# 1. How many listings are there with a price less than 100?
#
#
# 2. Find how many listings there are in just Brooklyn.
#
#
# 3. Find how many listings there are in Brooklyn with a price less than 100.
#
#
# 4. Using `.isin()` select anyone that has the host name of Michael, David, John, and Daniel.
#
#
# 5. Create a new column called `adjusted_price` that has $100 added to every listing in Williamsburg.  The prices for all other listings should be the same as the were before.
#
#
# 6. What % of the rooms are private, and what % of the rooms are shared.
#     * Hint, use `.value_counts()`

# %%
# 1. How many listings are there with a price less than 100? 


condition1 = file['price'] < 100 
ans = file[condition1]
ans.shape
# Out:
# (22778, 16)

# %%
# 2. Make a new DataFrame of listings in Brooklyn named `df_bk` 
# and find how many listings in just Brooklyn.

condition_bk = file['neighbourhood_group'] == 'Brooklyn' 
ans_bk = file[condition_bk]
ans_bk.head()
# Out:
#       id                                               name  host_id  \
# 1   3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2   5121                                    BlissArtsSpace!     7356
# 3   5136           Spacious Brooklyn Duplex, Patio + Garden     7378
# 8   5803     Lovely Room 1, Garden, Best Area, Legal rental     9744
# 11  6848                   Only 2 stops to Manhattan studio    15991
#
#         host_name neighbourhood_group       neighbourhood  latitude  \
# 1     LisaRoxanne            Brooklyn        Clinton Hill  40.68514
# 2           Garon            Brooklyn  Bedford-Stuyvesant  40.68688
# 3         Rebecca            Brooklyn         Sunset Park  40.66120
# 8          Laurie            Brooklyn         South Slope  40.66829
# 11  Allen & Irina            Brooklyn        Williamsburg  40.70837
#
#     longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %%
# 3. Find how many listings there are in Brooklyn with a price less than 100.

ans_together = file[condition1 & condition_bk]
ans_together.shape
# Out:
# (10473, 16)

# %%
# 4. Using `.isin()` select anyone that has the host name of Michael, David, John, and Daniel.

list_of_host = ['Michael', 'David', 'John', 'Daniel']

select_statement = file.host_name.isin(list_of_host)
# reverse the statement 
file[select_statement]
# Out:
#              id                                               name    host_id  \
# 52        16595  LOFT HAVEN ~ Six Windows ~ Bricks ~ Plants ~ Q...      64522
# 201       61747              Cozy,  Brooklyn, Prospect Park Studio     299370
# 209       62903  Beautiful modern studio apartment in heart of NYC     306605
# 220       64015                       Prime East Village 1 Bedroom     146944
# 260       74073       Food & Music Dream Apartment in Williamsburg     211877
# ...         ...                                                ...        ...
# 46362  44639591  Central & Stylish 1 Bedroom Apt - Heart of Che...  286136716
# 46396  44661297                       Flushing Sunshine home  #101  361579037
# 46403  44662157                        Flushing Sunshine home #102  361579037
# 46455  44697211                           David’s Queen Sized Room  343477029
# 46508  44797527    Long-Term: Furnished Apt in Nolita w/ Amenities   19448640
#
# ...

# %%
# 5. Create a new column called `adjusted_price` that has $100 added to every listing in Williamsburg.  
# The prices for all other listings should be the same as the were before. 

newCondition = file['neighbourhood'] == 'Williamsburg'
file['adjusted_price'] = np.where( newCondition, file['price'] + 100, file['price'])
ans_newprice = file[newCondition]
ans_newprice
# Out:
#              id                                               name    host_id  \
# 11         6848                   Only 2 stops to Manhattan studio      15991
# 15         7801                   Sweet and Spacious Brooklyn Loft      21207
# 35        14290                         * ORIGINAL BROOKLYN LOFT *      56104
# 38        14377                   Williamsburg 1 bedroom Apartment      56512
# 42        15385                              Very, very cozy place      60252
# ...         ...                                                ...        ...
# 46484  44746041      Modern, light-filled apartment in Wiliamsburg    3317380
# 46489  44749327  Luxury 3 bedroom apartment Williamsburg ROOF P...  334780877
# 46493  44753863            Bright, spacious East Williamsburg loft   38062951
# 46513  44800276        Williamsburg 1 Bedroom, Spacious and Classy  361034257
# 46517  44802032                  A very large room in Williamsburg  213793805
#
# ...

# %%
# 6. What % of the rooms are private, and what % of the rooms are shared.  

percentage = file.room_type.value_counts() / file.room_type.value_counts().sum()
percentage
# Out:
# Entire home/apt    0.515787
# Private room       0.454446
# Shared room        0.021213
# Hotel room         0.008554
# Name: room_type, dtype: float64

# %% [markdown]
# # Exercise 3 - Grouping
#
# 1. Using `groupby`, count how many listings are in each neighbourhood_group.
#
#
# 2. Using `groupby`, find the mean price for each of the neighbourhood_groups.
#
#
# 3. Using `groupby` and `.agg()`, find the min and max price for each of the neighbourhood_groups.
#
#
# 4. Using `groupby`, find the median price for each room type in each neighbourhood_group.
#
#
# 5. Using `groupby` and `.agg()`, find the count, min, max, mean, median, and std of the prices for each room type in each neighbourhood_group.

# %%
# 1. Using `groupby`, count how many listings are in each neighbourhood_group.

neighbourhood_group = file.groupby('neighbourhood_group')
ans_gby = len(neighbourhood_group)
ans_gby
# Out:
# 5

# %%
# 2. Using `groupby`, find the mean price for each of the neighbourhood_groups. 

neighbourhood_group['price'].mean()
# Out:
# neighbourhood_group
# Bronx             92.751479
# Brooklyn         120.225258
# Manhattan        191.880466
# Queens            99.754965
# Staten Island    110.947214
# Name: price, dtype: float64

# %%
# 3. Using `groupby` and `.agg()`, find the min and max price for each of the neighbourhood_groups. 

neighbourhood_group['price'].agg( ['min', 'max'] )
# Out:
#                      min    max
# neighbourhood_group
# Bronx                 16   1404
# Brooklyn               0  10000
# Manhattan              0  10000
# Queens                 0  10000
# Staten Island         19   1200

# %%
# 4. Using `groupby`, find the mean price for each room type in each neighbourhood_group.
group_by_options=['room_type','neighbourhood_group']
groupby_room_neighbourhood_group = file.groupby(group_by_options)
groupby_room_neighbourhood_group['price'].mean()
# Out:
# room_type        neighbourhood_group
# Entire home/apt  Bronx                  138.004819
#                  Brooklyn               171.587687
#                  Manhattan              231.335572
#                  Queens                 150.168900
#                  Staten Island          151.720930
# Hotel room       Brooklyn               147.300000
#                  Manhattan              292.515670
#                  Queens                 139.058824
# Private room     Bronx                   68.419668
#                  Brooklyn                71.291189
#                  Manhattan              128.277069
#                  Queens                  69.972564
#                  Staten Island           70.312883
# Shared room      Bronx                   66.391304
#                  Brooklyn                57.870091
#                  Manhattan              111.735084
#                  Queens                  89.891892
#                  Staten Island           46.000000
# ...

# %%
# 5. Using `groupby` and `.agg()`, find the count, min, max, mean, median, and std of the prices 
# for each room type in each neighbourhood_group.

groupby_room_neighbourhood_group['price'].agg( ['min', 'max','mean','median','std'] )
# Out:
#                                      min    max        mean  median  \
# room_type       neighbourhood_group
# Entire home/apt Bronx                 25   1404  138.004819   103.0
#                 Brooklyn              20  10000  171.587687   135.0
#                 Manhattan              0  10000  231.335572   165.0
#                 Queens                10  10000  150.168900   115.0
#                 Staten Island         39   1200  151.720930   111.0
# Hotel room      Brooklyn               0    399  147.300000   129.0
#                 Manhattan              0   2211  292.515670   210.0
#                 Queens                 0    249  139.058824   149.0
# Private room    Bronx                 16    700   68.419668    55.0
#                 Brooklyn              10   2500   71.291189    60.0
#                 Manhattan             10  10000  128.277069    80.0
#                 Queens                18   9000   69.972564    55.0
# ...

# %% [markdown]
# # Join and file saving.
# 1. Load the `prices.csv` and the `n_listings.csv`
#
#
# 2. Do join that keeps all the records for each table.
#     * Neighbourhood groups should include ['Bronx', 'Brooklyn', 'Manhattan', 'Queens', 'Staten Island',
#        'LongIsland']
#
#
# 3. Save your joined csv as `joined.csv`
#
#
# 4. Load your saved table and see if it looks the same or different that the DataFrame you used to create it.

# %%
# 1. Load the `prices.csv` and the `n_listings.csv`
# the seperater here is ; not ,
dflistings = pd.read_csv('data/n_listings.csv', sep=';')
dfprices = pd.read_csv('data/prices.csv', sep=',')

# %%
# 2. Do join that keeps all the records for each table.
dfjoined = pd.merge(dfprices, dflistings, on='neighbourhood_group', how='outer')

dfjoined
# Out:
#   neighbourhood_group   mean_price  n_listings
# 0               Bronx    92.751479      1183.0
# 1            Brooklyn   120.225258     18632.0
# 2           Manhattan   191.880466     20580.0
# 3              Queens    99.754965         NaN
# 4       Staten Island   110.947214         NaN
# 5          LongIsland          NaN      4121.0

# %% [markdown]
# # Use the grammys.csv data for the next section of questions.
#
# 1. Who was won Album of the Year in 2016?
#
#
# 2. Who won Best Rap Album in 2009?
#
#
# 3. How many awards was Kendrick Lamar nomiated for, and how many did he win...?

# %%
fdGrammys = pd.read_csv('data/grammys.csv', sep=',')
fdGrammys
# Out:
#       year                                           category  \
# 0     1959                                  Album of the Year
# 1     1959                                   Best Album Cover
# 2     1959                                   Best Arrangement
# 3     1959  Best Classical Performance - Chamber Music (in...
# 4     1959  Best Classical Performance - Instrumentalist (...
# ...    ...                                                ...
# 6318  2019                                 Record of the Year
# 6319  2019                                   Song of the Year
# 6320  2019                                   Song of the Year
# 6321  2019                                   Song of the Year
# 6322  2019                                   Song of the Year
#
#                                  nominee  \
# 0             The Music from Peter Gunn.
# 1                        Only the Lonely
# 2              The Music From Peter Gunn
# 3                 Beethoven: Quartet 130
# ...

# %%
#  1. Who was won Album of the Year in 2016?
condition1 = fdGrammys['category'] == 'Album of the Year'
condition2 = fdGrammys['year'] == 2016
condition3 = fdGrammys['winner'] == True
ans_who = fdGrammys[condition1 & condition2 & condition3]
ans_who
# Out:
#       year           category nominee  \
# 5505  2016  Album of the Year   1989.
#
#                                                 workers  winner
# 5505  Taylor Swift (artist/producer), Jack Antonoff ...    True

# %%
# 2. Who won Best Rap Album in 2009?
condition1 = fdGrammys['category'] == 'Best Rap Album'
condition2 = fdGrammys['year'] == 2009
condition3 = fdGrammys['winner'] == True
ans_who = fdGrammys[condition1 & condition2 & condition3]
ans_who
# Out:
#       year        category         nominee     workers  winner
# 4396  2009  Best Rap Album  Tha Carter III  Lil' Wayne    True

# %%
# 3. How many awards was Kendrick Lamar nomiated for, and how many did he win...?
KL = fdGrammys['workers'] == 'Kendrick Lamar'
win = fdGrammys['winner'] == True
nomiated = fdGrammys[KL]
nomiated
# Out:
#       year              category                  nominee         workers  \
# 5269  2014        Best Rap Album  Good Kid, M.A.A.D City.  Kendrick Lamar
# 5272  2014  Best Rap Performance  Swimming Pools (Drank).  Kendrick Lamar
# 5448  2015  Best Rap Performance                       i.  Kendrick Lamar
# 5596  2016        Best Rap Album     To Pimp a Butterfly.  Kendrick Lamar
# 5599  2016  Best Rap Performance                 Alright.  Kendrick Lamar
# 6003  2018  Best Rap Performance                  HUMBLE.  Kendrick Lamar
#
#       winner
# 5269   False
# 5272   False
# 5448    True
# 5596    True
# 5599    True
# 6003    True

# %%
win_award = fdGrammys[KL & win]
