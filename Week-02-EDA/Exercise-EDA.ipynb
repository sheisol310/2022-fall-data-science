# %% [markdown]
# # Exploratory Data Analysis Exercise
# * For this part we will be using the `data/cars.csv` dataset

# %%
import pandas as pd
import numpy as np
# Matplotlib is a cross-platform, data visualization and graphical plotting library for Python and its numerical extension NumPy.
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %matplotlib inline 
# the %matplotlib inline will make your plot outputs appear and be stored within the notebook.
import scipy.stats as stats

df = pd.read_csv('data/cars.csv')
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#   Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# ...

# %% [markdown]
# # Load in the data
# * Use the file in the data folder called 'cars.csv'
# * Save it as a varible named 'df'
# * Display the first 5 rows of our dataframe

# %%
# Load data
df = pd.read_csv('data/cars.csv')
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#   Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# ...

# %% [markdown]
# # Data clean up part 1.
#
# 1. Print the number of duplicate rows we have in our dataframe.
#
# 2. Modify our df to have all duplicate rows removed.
#
# 3. Do a sanity check to make sure all duplicates have been removed by printing the total number of duplicate rows again.

# %%
# 1. Print the number of duplicate rows we have in our dataframe.

df.duplicated().sum()
# Out:
# 720

# %%
#  2. Modify our df to have all duplicate rows removed. 
# Ask students to solve this one...
print(df.shape, 'before dropping dupes')

# Another way to do the same thing
df = df.drop_duplicates()

print(df.shape, 'after dropping dupes')
# Out:
# (11914, 15) before dropping dupes
# (11194, 15) after dropping dupes

# %%
# 3. Do a sanity check to make sure all duplicates have been removed by printing the total number of duplicate rows again.
df.duplicated()
# all res of row are False and the length of duplicates is 11194 where it matches the number after dropping dupes.
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11194, dtype: bool

# %% [markdown]
# # Data clean up part 2.
# * Which column has the most null values and how many null values does it have?
# * Print how long our dataframe is.
# * Remove any row that has a null value in it.
# * Do a sanity check and pring how long our dataframe is now that we have removed our null values.

# %%
# * Which column has the most null values and how many null values does it have?
df.isnull().sum().sort_values(ascending=False)
# the col 'Engine HP' has the maximum null value of 69
# Out:
# Engine HP            69
# Engine Cylinders     30
# Number of Doors       6
# Engine Fuel Type      3
# Make                  0
# Model                 0
# Year                  0
# Transmission Type     0
# Driven_Wheels         0
# Vehicle Size          0
# Vehicle Style         0
# highway MPG           0
# city mpg              0
# Popularity            0
# MSRP                  0
# dtype: int64

# %%
# * Print how long our dataframe is.
print(df.shape, 'before df.dropna()')
# Out:
# (11194, 15) before df.dropna()

# %%
# * Remove any row that has a null value in it. 
df = df.dropna()

# %%
# * Do a sanity check and pring how long our dataframe is now that we have removed our null values.

print(df.shape, 'after df.dropna()')
# Out:
# (11092, 15) after df.dropna()

# %% [markdown]
# ### Make a bar chart that displays how many times each brand of car appears in this data.
# _Brand of car is the `Make` of the car._
# * You can achieve this by using value_counts or by a groupby.  Either is fine with me.

# %%
df.head()
# check the headline of colum
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#   Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# ...

# %%
# Make a bar chart that displays how many times each brand of car appears in this data. 
# 1. gorup by data by Make col
# 2. count the total of each Make of brand
# 3. Draw a bar char with brand_num and Make name
gb = df.groupby('Make') 
brand_num = gb['Make'].count()
brand_num.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Make'>

# %% [markdown]
# # Make the cart more legible, by making it a horizontal bar chart and changing the figure size.  And also sort the values so the bar chart displays from lowest to highest.

# %%
# Make the cart more legible, by making it a horizontal bar chart, sorting the values, and changing the figure size.
brand_num = gb['Make'].count().sort_values(ascending=False)
brand_num.plot(kind='barh', figsize=(15,9))
# barh = bar chart in horizontal
# figsize(float, float),(default: [6.4, 4.8]) Width, height in inches.
# sort brand_num
# Out:
# <AxesSubplot:ylabel='Make'>

# %% [markdown]
# # Make a timeline line chart in which the x-axis is the year, and the y-axis is the average MSRP.
# * What's noticeable about it and what do you think the error is...

# %%
# Make a timeline line chart in which the x-axis is the year, and the y-axis is the average MSRP.
gb_year = df.groupby('Year')
mean_MSRP = gb_year['MSRP'].mean()
mean_MSRP.plot(kind='line',x='Year', y='MSRP')
# group by the data with YEAR col - data x
# cal the mean(average) for MSRP
# plot the line chart with x year and y MSRP
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# # It seems as though in the years before (and includig) 2000, they were counting in tens.
# Make a new column that is called `adjusted_price`, that contains all prices, however, for every year before 2000 make it 10x the original MSRP.
#    * Hint; you might need to use our old friend `np.where`

# %%
# Make a column where is 10 when year is less than 2000, else 1.
df['adjusted_price'] = np.where(df['Year'] <= 2000, 10, 1)
# df['adjusted_price']: new col that we are going to add by using np.where
# np.where(condition, True then?, False then?)

# Multiply the MSRP by the price adjuster.
df['adjusted_price'] = df['MSRP']*df['adjusted_price']

# %% [markdown]
# # Replot the new adjusted price.
# * Make the y-axis start at 0 and go up to 100,000

# %%
# Plot new prices
gb_new_year = df.groupby('Year')
mean_new_MSRP = gb_new_year['adjusted_price'].mean()
mean_new_MSRP.plot(kind='line',x='Year', ylim=(0,100000))
# ylim is set limit to y-axis from 0 to 100,000
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# # What are top 5 car makers that make the most expensive cars on average.
# * I only want the top 5, make sure your answer is the top 5 and only the top 5. (hint, you can use .head())
# * Use our `adjusted_price` column for this
# * Hint; you're going to have to do a .groupby to answer this.

# %%
# What are the top 5 car makers make the most expensive cars on average. 
top5 = df.groupby('Make')
top5['adjusted_price'].mean().round().nlargest(5)
# group data by maker
# mean() function cal aver car price in different makers
# round deals with e sign
# nlargest or do head()
# Out:
# Make
# Bugatti        1757224.0
# Maybach         546222.0
# Rolls-Royce     351131.0
# Lamborghini     331567.0
# Bentley         247169.0
# Name: adjusted_price, dtype: float64

# %% [markdown]
# # What are the 5 car makers that have the highest median highway MPG?

# %%
# Which car makers have the highest median highway MPG?

top5['highway MPG'].median().head()
# Out:
# Make
# Acura           28.0
# Alfa Romeo      34.0
# Aston Martin    19.0
# Audi            28.0
# BMW             28.0
# Name: highway MPG, dtype: float64

# %% [markdown]
# # Using `sns.histplot`, make histogram of the adjusted_price of just these car makers.
# * ['Chevrolet', 'Ford', 'Toyota']
# * Create a temp_df to store the dataframe of just these values.
# * Set the 'hue='Make''.

# %%
# Using `sns.histplot`, make histogram of the adjusted_price of just these car makers.
# It is used to summarize discrete or continuous data that are measured on an interval scale. It is often used to illustrate the major features of the distribution of the data in a convenient form
c1 = df['Make'] == 'Chevrolet'
c2 = df['Make'] == 'Ford'
c3 = df['Make'] == 'Toyota'
temp_df = df[c1 | c2 | c3] 
sns.histplot(data=temp_df, 
                x='adjusted_price', 
                hue='Make');
# x is car price
# y is times of the car price
# hue is the label of makers

# %% [markdown]
# # Remake the same histogram, but limit the x-axis from 0 to 100,000

# %%
# Remake the same histogram, but limit the x-axis from 0 to 100,000
adjust_x = sns.histplot(data=temp_df, 
                x='adjusted_price', 
                hue='Make');
adjust_x.set_xlim(0, 100000)
# Out:
# (0.0, 100000.0)

# %% [markdown]
# # Plot the relationship between Engine HP and highway MPG

# %%
# Plot the relationship between Engine HP and highway MPG
# Plot the relationship = scatterplot
sns.scatterplot(data=temp_df, x = 'Engine HP', y = 'highway MPG' )
# Out:
# <AxesSubplot:xlabel='Engine HP', ylabel='highway MPG'>

# %% [markdown]
# # Using `sns.boxplot`, create a boxplot for the 'Engine HP'

# %%
# create a boxplot for the 'Engine HP'
sns.boxplot(data=temp_df, x='Engine HP')
# Out:
# <AxesSubplot:xlabel='Engine HP'>

# %% [markdown]
# # Make another boxplot for highway MPG

# %%
# create a boxplot for the 'highway MPG'
sns.boxplot(data=temp_df, x='highway MPG')
# Out:
# <AxesSubplot:xlabel='highway MPG'>

# %% [markdown]
# # Remove any  outliers from Engine HP and highway MPG
#
# <img src='https://miro.medium.com/max/1400/1*2c21SkzJMf3frPXPAR_gZA.png' width=500>
#
# * Outliers meaning values that are outside 1.5x the Inter Quartile Range (see image above).
# * For each column (Engine HP and highway MPG):
# * Calculate the 0.25 and 0.75 Quantiles
# * Calculate the Inter Quartile Range (IQR)
# * Create condition mask for the values that are outliers below (in the 'Minimum' range).
# * Create condition mask for the values that are outliers above (in the 'Maximum' range).
# * Filter the dataframe to remove any values that are in the above section _OR_ the below section. (hint; it may be easier to use the inverse selection '~'.
# * Make the same boxplots of Engine HP and Highway MPG as before but with the this dataframe.

# %%
# Remove any  outliers from Engine HP and highway MPG 
# Calculate Q1
Q1_HP = temp_df['Engine HP'].quantile(0.25)
Q1_MPG = temp_df['highway MPG'].quantile(0.25)

# # # Calculate Q3
Q3_HP = temp_df['Engine HP'].quantile(0.75)
Q3_MPG = temp_df['highway MPG'].quantile(0.75)

# # # Define the Inter Quartile Range (IQR)
IQR_HP = Q3_HP - Q1_HP
IQR_MPG = Q3_MPG - Q1_MPG

# # # Make select condition for the values that fall below the Q1 - 1.5*IQR
outliers_below_HP = temp_df['Engine HP'] < (Q1_HP - 1.5 * IQR_HP)
outliers_below_MPG = temp_df['highway MPG'] < (Q1_MPG - 1.5 * IQR_MPG)

# # # Make select condition for the values that fall above the Q3 - 1.5*IQR
outliers_above_HP = temp_df['Engine HP'] > (Q3_HP + 1.5 * IQR_HP)
outliers_above_MPG = temp_df['highway MPG'] > (Q3_MPG + 1.5 * IQR_MPG)

# # # Select the INVERSE of the selection
temp_df = temp_df[~(outliers_below_HP | outliers_above_HP | outliers_below_MPG |outliers_above_MPG)]

# %%
temp_df
# Out:
#          Make    Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 479    Toyota  4Runner  2014  regular unleaded      270.0               6.0
# 480    Toyota  4Runner  2014  regular unleaded      270.0               6.0
# 481    Toyota  4Runner  2014  regular unleaded      270.0               6.0
# 482    Toyota  4Runner  2014  regular unleaded      270.0               6.0
# 483    Toyota  4Runner  2014  regular unleaded      270.0               6.0
# ...       ...      ...   ...               ...        ...               ...
# 11827  Toyota    Yaris  2017  regular unleaded      106.0               4.0
# 11828  Toyota    Yaris  2017  regular unleaded      106.0               4.0
# 11829  Toyota    Yaris  2017  regular unleaded      106.0               4.0
# 11830  Toyota    Yaris  2017  regular unleaded      106.0               4.0
# 11831  Toyota    Yaris  2017  regular unleaded      106.0               4.0
#
# ...

# %% [markdown]
# # Remake the boxplots for both Engine HP and highway MPG

# %%
# Engine HP boxplot
sns.boxplot(data=temp_df, x='Engine HP')
# Out:
# <AxesSubplot:xlabel='Engine HP'>

# %%
# highway MPG boxplot
sns.boxplot(data=temp_df, x='highway MPG')
# Out:
# <AxesSubplot:xlabel='highway MPG'>

# %% [markdown]
# # Make a scatter plot of Engine HP vs highway MPG

# %%
# Make a scatter plot of Engine HP vs highway MPG
sns.scatterplot(data=temp_df, x = 'Engine HP', y = 'highway MPG' )
# Out:
# <AxesSubplot:xlabel='Engine HP', ylabel='highway MPG'>

# %% [markdown]
# # What does this plot tell you about how Engine HP affects highway MPG?

# %%
# What does this plot tell you about how Engine HP affects highway MPG?

print('As Engine HP increases, Highway MPG decreases.')
# Out:
# As Engine HP increases, Highway MPG decreases.

# %% [markdown]
# # Using a pairplot, display all of the linear relationship.
# * Which variables look like they have the strongest linear relationship (Besides MSRP and adjusted_price).

# %%
# Using a pairplot, display all of the linear relationship.

sns.pairplot(temp_df);

# %%
# * Which variables look like they have the strongest linear relationship (Besides MSRP and adjusted_price).

print('hightway MPG vs city MPG')
# Out:
# hightway MPG vs city MPG

# %% [markdown]
# # Find which features actually have the strongest linear relationship using correlations.
# * Make a heatmap plot of all of the correlations in our dataset.
# * Change the figure size of our heatmap plot to be 8x8
# * __Which feature does Engine HP have the strongest relationship with, and why do you think that relationship exists.__

# %%
# * Make a heatmap plot of all of the correlations in our dataset.
# * Change the figure size of our heatmap plot to be 8x8
plt.figure(figsize=(8,8))
sns.heatmap(temp_df.corr(), annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
# Which feature does Engine HP have the strongest relationship with, and why do you think that relationship exists.

print('Beside the MSRP, Engine HP has the strongest relationship with Engine Cylinders. Look at the cube of value 0.77')
# Out:
# Beside the MSRP, Engine HP has the strongest relationship with Engine Cylinders. Look at the cube of value 0.77

# %% [markdown]
# # [EXTRA CREDIT]
# * In the column names, replace all the spaces with an underscore, and make them all lowercase as well

# %%
# * In the column names, replace all the spaces with an underscore, and make them all lowercase as well
df.columns = df.columns.str.replace(' ', '_')
df = df.rename(columns = str.lower)
df.head()

# columns = Manipulate the col
# str.replace = str func with replace operation
# cloumns = str(all str.lower func)
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#   vehicle_size vehicle_style  highway_mpg  city_mpg  popularity   msrp  \
# ...
